# %%
import pickle

## All of it because our df_train.csv isn't actually a real csv file it's more likely a binary file
with open(
    r"C:\Users\moazz\Desktop\Earthquake Project\dataset\df_train.csv", "rb"
) as f:
    df = pickle.load(f)

# %%
df.shape
# Out:
# (34289, 45)

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'E_channel', 'N_channel', 'E_channel_precursors',
#        'N_channel_precursors', 'Z_channel_precursors', 'Z_channel',
#        'back_azimuth_deg', 'coda_end_sample', 'network_code',
#        'p_arrival_sample', 'p_status', 'p_travel_sec', 'p_weight',
#        'receiver_code', 'receiver_elevation_m', 'receiver_latitude',
#        'receiver_longitude', 'receiver_type', 's_arrival_sample', 's_status',
#        's_weight', 'snr_db', 'source_depth_km', 'source_depth_uncertainty_km',
#        'source_distance_deg', 'source_distance_km', 'source_error_sec',
#        'source_gap_deg', 'source_horizontal_uncertainty_km', 'source_id',
#        'source_latitude', 'source_longitude', 'source_magnitude',
#        'source_magnitude_author', 'source_magnitude_type',
#        'source_mechanism_strike_dip_rake', 'source_origin_time',
#        'source_origin_uncertainty_sec', 'trace_category', 'trace_name',
#        'trace_start_time', 'missing_time_from_event',
#        'source_magnitude_label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34289 entries, 0 to 34288
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   level_0                           34289 non-null  int64
#  1   index                             34289 non-null  int64
#  2   E_channel                         34289 non-null  object
#  3   N_channel                         34289 non-null  object
#  4   E_channel_precursors              34289 non-null  object
#  5   N_channel_precursors              34289 non-null  object
#  6   Z_channel_precursors              34289 non-null  object
#  7   Z_channel                         34289 non-null  object
#  8   back_azimuth_deg                  34289 non-null  object
#  9   coda_end_sample                   34289 non-null  object
#  10  network_code                      34289 non-null  object
#  11  p_arrival_sample                  34289 non-null  int64
#  12  p_status                          34289 non-null  object
#  13  p_travel_sec                      34289 non-null  object
#  14  p_weight                          34289 non-null  object
#  15  receiver_code                     34289 non-null  object
#  16  receiver_elevation_m              34289 non-null  object
#  17  receiver_latitude                 34289 non-null  object
#  18  receiver_longitude                34289 non-null  object
#  19  receiver_type                     34289 non-null  object
#  20  s_arrival_sample                  34289 non-null  object
#  21  s_status                          34289 non-null  object
#  22  s_weight                          34289 non-null  object
#  23  snr_db                            34289 non-null  object
#  24  source_depth_km                   34289 non-null  object
#  25  source_depth_uncertainty_km       34289 non-null  object
#  26  source_distance_deg               34289 non-null  object
#  27  source_distance_km                34289 non-null  float64
#  28  source_error_sec                  31521 non-null  object
#  29  source_gap_deg                    28608 non-null  object
#  30  source_horizontal_uncertainty_km  34289 non-null  object
#  31  source_id                         34289 non-null  object
#  32  source_latitude                   34289 non-null  object
#  33  source_longitude                  34289 non-null  object
#  34  source_magnitude                  34289 non-null  float64
#  35  source_magnitude_author           34289 non-null  object
#  36  source_magnitude_type             34289 non-null  object
#  37  source_mechanism_strike_dip_rake  34289 non-null  object
#  38  source_origin_time                34289 non-null  datetime64[ns]
#  39  source_origin_uncertainty_sec     27067 non-null  object
#  40  trace_category                    34289 non-null  object
#  41  trace_name                        34289 non-null  object
#  42  trace_start_time                  34289 non-null  datetime64[ns]
#  43  missing_time_from_event           34289 non-null  float64
#  44  source_magnitude_label            34289 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(3), object(37)
# memory usage: 11.8+ MB

# %% [markdown]
# ### SOME REGULAR EDA(EXPLORATARY DATA ANALYSIS) TO GET TO KNOW WHAT KIND OF OUR REALLY IS

# %%
df.head()
# Out:
#    level_0   index                                          E_channel  \
# 0     6000    2508  [-0.0, -0.3037471, -0.7941901, -2.0677443, -2....
# 1     6001  177771  [0.0, 0.008827989, 0.027690079, 0.050335042, 0...
# 2     6002  143069  [-0.0, -0.07114574, -0.07915803, 0.045831945, ...
# 3     6003  176271  [-4.039773, -5.0321927, -3.098704, -2.0527992,...
# 4     6004   44864  [0.0, 0.0046114475, 0.01731589, 0.057890795, 0...
#
#                                            N_channel  \
# 0  [-0.0, -0.1688106, -0.4445446, -1.1667616, -1....
# 1  [0.0, 0.0067506083, 0.017026894, 0.0626213, 0....
# 2  [-0.0, -0.11352274, -0.40909925, -0.6154829, -...
# 3  [-1.1656461, -0.06951267, 2.7692225, 2.9919803...
# 4  [-0.0, -0.008839174, -0.03844553, -0.08942565,...
#
#                                 E_channel_precursors  \
# 0  [-174.67068, -160.9165, -111.053535, -55.44577...
# 1  [11.102617, 20.359272, 22.870697, 9.638555, 11...
# 2  [550.5055, 621.12805, 494.6476, 227.99667, -8....
# 3  [6.2956905, 10.219786, 5.2689557, -0.8171556, ...
# 4  [-42.98916, -48.740185, -76.14363, -64.10923, ...
#
#                                 N_channel_precursors  \
# 0  [-165.62244, -131.0894, -92.94777, -50.196747,...
# 1  [18.403194, 5.542464, -8.4973955, -8.423143, 0...
# 2  [672.15076, 618.96216, 396.99496, 218.53148, 9...
# 3  [0.7568476, 2.7275038, 0.7710497, 2.6436691, 3...
# 4  [-28.852701, -9.431699, -17.502617, -8.581977,...
#
#                                 Z_channel_precursors  \
# 0  [34.627823, 6.5667224, -19.73172, -63.976402, ...
# 1  [4.857739, 13.261822, 16.091331, 21.411762, 15...
# 2  [-51.757576, 128.74973, 153.27184, 69.25438, 4...
# 3  [0.84727585, -0.23956358, -0.18065163, 3.83636...
# 4  [30.556585, 10.862256, 45.766666, 30.64336, 17...
#
#                                            Z_channel back_azimuth_deg  \
# 0  [-0.0, -0.040024515, -0.085517466, -0.22547446...            136.0
# 1  [0.0, 0.0044994447, 0.012301209, 0.036946297, ...       204.300003
# 2  [-0.0, -0.02897907, 0.03212849, 0.31494758, 0....        46.099998
# 3  [-0.33165205, -1.1276397, -0.23394835, -0.2988...       309.799988
# 4  [0.0, 0.06398069, 0.17558555, 0.45652658, 0.61...       334.899994
#
#   coda_end_sample  ... source_magnitude_author  source_magnitude_type  \
# 0      [[3199.0]]  ...                    None                     ml
# 1      [[3097.0]]  ...                    None                     ml
# 2      [[1928.0]]  ...                    None                     ml
# 3      [[2641.0]]  ...                    None                     ml
# 4      [[3199.0]]  ...                    None                     ml
#
#   source_mechanism_strike_dip_rake      source_origin_time  \
# 0                             None 2018-06-15 07:09:57.260
# 1                             None 2009-07-15 00:58:07.600
# 2                             None 2003-02-22 13:37:30.670
# 3                             None 2018-07-26 18:46:42.410
# 4                             None 2013-03-13 22:34:50.480
#
#   source_origin_uncertainty_sec    trace_category                 trace_name  \
# 0                          None  earthquake_local  HSSD.HV_20180615070953_EV
# 1                          0.83  earthquake_local  CERT.IV_20090715005807_EV
# 2                          None  earthquake_local   SVD.CI_20030222133726_EV
# 3                          None  earthquake_local  B084.PB_20180726184643_EV
# 4                          0.82  earthquake_local   DOI.IV_20130313223451_EV
#
#          trace_start_time missing_time_from_event source_magnitude_label
# 0 2018-06-15 07:09:54.030                   -3.23        [0, 0, 1, 0, 0]
# 1 2009-07-15 00:58:08.900                    1.30        [0, 0, 0, 1, 0]
# 2 2003-02-22 13:37:27.020                   -3.65        [0, 1, 0, 0, 0]
# 3 2018-07-26 18:46:43.600                    1.19        [0, 0, 0, 1, 0]
# 4 2013-03-13 22:34:52.420                    1.94        [0, 0, 1, 0, 0]
#
# [5 rows x 45 columns]

# %%
type(df["Z_channel"].iloc[0])
# Out:
# numpy.ndarray

# %%
len(df["Z_channel"].iloc[0])
# Out:
# 6000

# %%
df[["p_arrival_sample", "s_arrival_sample"]].head()
# Out:
#    p_arrival_sample s_arrival_sample
# 0               898           1322.0
# 1               900           1730.0
# 2               900           1317.0
# 3              1000           1811.0
# 4               900           1677.0

# %%
df["Z_channel"].apply(len).value_counts()
# Out:
# Z_channel
# 6000    34289
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Only 1 Signal

# %%
import matplotlib.pyplot as plt

signal = df["Z_channel"].iloc[0]

plt.figure(figsize=(16,8))
plt.plot(signal)
plt.title("Raw Z-channel earthquake signal")
plt.xlabel("Time (samples)")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# #### In above figure we see that:
# ##### - X axis(0 ---> 6000) represent time moving forward(moment by moment)
# ##### - Y axis(Up and Down) represent up and down how much the ground moved up/down at that moment

# %% [markdown]
# ### MARKING P and S arrival

# %%
p = df["p_arrival_sample"].iloc[0]
s = df["s_arrival_sample"].iloc[0]

plt.figure(figsize=(12,4))
plt.plot(signal)
plt.axvline(p, color="green", label="P-wave")
plt.axvline(s, color="red", label="S-wave")
plt.legend()
plt.title("Earthquake signal with P & S arrival")
plt.show()
